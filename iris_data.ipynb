# %% [markdown]
# <a href="https://colab.research.google.com/github/nadeem53/Iris_Data_Analysis/blob/main/iris_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import pandas as pd
import numpy as bp
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load datsets
iris_df = pd.read_csv("/content/Iris.csv")

# %%
#Eexplore data
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# last five rows
iris_df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
#check info of the datsets
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#describe the datasets
iris_df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#check is there any null values
iris_df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#check the null values with plot
sns.heatmap(iris_df.isnull(), yticklabels= False, cbar = False, cmap= 'viridis')
# Out:
# <Axes: >

# %% [markdown]
# **The Above plot shows there is no null values in datastes.**

# %%
sns.boxplot(data=iris_df, y='SepalLengthCm')
plt.show()

# %%
Q1 = iris_df['SepalLengthCm'].quantile(0.25)
Q3 = iris_df['SepalLengthCm'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = iris_df[(iris_df['SepalLengthCm'] < lower_bound) | (iris_df['SepalLengthCm'] > upper_bound)]

# %%
# Data Visualization
sns.pairplot(iris_df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets

# Load the Iris dataset
iris = datasets.load_iris()
X = iris.data
y = iris.target

# Convert the data into a DataFrame for easier plotting
iris_df = sns.load_dataset('iris')

# Scatter plot for Sepal Length vs Sepal Width
sns.scatterplot(x='sepal_length', y='sepal_width', hue='species', data=iris_df)
plt.title("Scatter plot of Sepal Length vs Sepal Width")
plt.show()

# %% [markdown]
# **Above plot show sepal length vs sepal width.**

# %%
# Scatter plot for Petal Length vs Petal Width
sns.scatterplot(x='petal_length', y='petal_width', hue='species', data=iris_df)
plt.title("Scatter plot of Petal Length vs Petal Width")
plt.show()

# %% [markdown]
# Above plot show the petal length vs petal width.

# %%
# Pair plot to visualize relationships between all pairs of features
sns.pairplot(iris_df, hue='species', markers=["o", "s", "D"])
plt.title("Pair Plot of Iris Dataset")
plt.show()

# %% [markdown]
# **IT's a pair plot of iris datsets.**
